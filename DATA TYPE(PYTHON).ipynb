# %% [markdown]
# Data Types
#  . 1.Fundamental Data Types
#      .int
#      .Float
#      .Complex
#      .boolean
#      .string
#
#  . 2. Advanced Data Types or Containers or Data structure
#        .range
#        .list
#        .tuple
#        .set
#        .dictonaries
#
#
#
#
#  Int: Integer literals are created by any number without a decimal or complex component.

# %%
a=10

# %%
type(a)
# Out:
# int

# %% [markdown]
# Float

# %%
a=10.0
type(a)
# Out:
# float

# %%
a=3
print(type(a))

b=3.0
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a = 3
b = 5.0
a+b
# Out:
# 8.0

# %% [markdown]
# Type Casting: Convert From one to another type: int(),float(),str()

# %%
b = 5.9
int(b)
# Out:
# 5

# %%
int(10.9999)
# Out:
# 10

# %% [markdown]
# Boolean

# %%
b1 = True
type(b1)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True+True
# Out:
# 2

# %%
b = 3.9
c = False
b+c
# Out:
# 3.9

# %% [markdown]
# Complex

# %% [markdown]
# .
# Complex literals can be created by using the notation x+yj where x is the real  component and y is the imaginary component.

# %%
x=10+20j

# %%
type(x)
# Out:
# complex

# %%
x.real
# Out:
# 10.0

# %%
x.imag
# Out:
# 20.0

# %%
int(x.imag)
# Out:
# 20

# %%
y = 1.0 - 2.0j
print(y.real, y.imag)
# Out:
# 1.0 -2.0

# %% [markdown]
# Strings
#
# .A strong in python consists of a series or sequence of characters - letters, numbers, and special characters.
# .We can use single quotes or double quotes to reprersent strings.
# .Multi-line strings can be denoted using triple quotes, ""or"""".
# .Strings can be indexed-often synonymously called subscripted as well.
# .The first character of a string has the index 0.

# %%
from re import M
myString1 = 'Hello'
print(myString1)

myString2 = "Hello"
print(myString2)

myString3 = '''Hello'''
print(myString3)
# Out:
# Hello
# Hello
# Hello

# %%
a = 'siva'
type(a)
# Out:
# str

# %%
a = 'siva'
# Try converting a to an integer after converting it to a number if possible.
try:
    a_int = int(float(a))
    print(a_int)
except ValueError:
    print("Cannot convert 'siva' to an integer.")
# Out:
# Cannot convert 'siva' to an integer.

# %%
type("siva")
# Out:
# str

# %%
var = "1234567"
type(var)
# Out:
# str

# %%
var
# Out:
# '1234567'

# %%
z=int(var)
z
# Out:
# 1234567

# %%
a= ' si@1234'
a
# Out:
# ' si@1234'

# %%
a = ' si@1234'
# Remove non-numeric characters before conversion
a_numeric = ''.join(c for c in a if c.isdigit())
int(a_numeric) # Now this should work if a_numeric is not empty
# Out:
# 1234

# %%
a='1234'

# %%
int(a)
# Out:
# 1234

# %%
print('navin "laptop"')
# Out:
# navin "laptop"

# %%
print("navin's \"laptop\"")
# Out:
# navin's "laptop"

# %% [markdown]
# Concatenation
# Joining of two or more strings into a single one is called concatenation.
# .The + operator does this in python.simply writing two strings literals together also concatenates them.
# .The + operator can be used to repeat the string for a given number of times.

# %%
a="50"
b="2"
a+b
# Out:
# '502'

# %%
int(a+b)
# Out:
# 502

# %%
int(a)+int(b)
# Out:
# 52

# %%
d = '3'
a = 6
a + int(d)  # Convert 'd' to an integer before adding
# Out:
# 9

# %%
int(d)+a
# Out:
# 9

# %%
int(d+str(a))
# Out:
# 36

# %%
a="siva"
b=123

# %%
print(a+str(b))
# Out:
# siva123

# %%
'navin'+'navin'
# Out:
# 'navinnavin'

# %%
"neeraj" * 5
# Out:
# 'neerajneerajneerajneerajneeraj'

# %%
user = "satish"
lines = 100

# %%
print("congratulations,",user,"! you just wrote",lines,"1ines of code")
# Out:
# congratulations, satish ! you just wrote 100 1ines of code

# %%
print("congratulations," + user + " ! you just wrote " + str(lines) + " lines of code")
# Out:
# congratulations,satish ! you just wrote 100 lines of code

# %% [markdown]
# Length of String

# %%
d = 'This is intresting'
len(d)
# Out:
# 18

# %% [markdown]
# Delete String

# %%
d = 'This is intresting'
len(d)
# The variable d is no longer available after this line
del d
# Let's define it again before printing
d = "This is still interesting"
print(d)
# Out:
# This is still interesting

# %% [markdown]
# How to access characters in a string using indexing.

# %%
myString = "Hello"

# %%
print(myString[0])
# Out:
# H

# %%
print(myString[-1])
# Out:
# o

# %%
print(myString[-3])#print character using negative indexing.
# Out:
# l

# %%
 #If we try to access index with out of the range,we will get index error.
 print(myString[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-08d2c980b2ca> in <cell line: 2>()
#       1 #If we try to access index with out of the range,we will get index error.
# ----> 2 print(myString[5])
#
# IndexError: string index out of range

# %%
# If we try to access by using use decimal number,we will get errors.
print(myString[1.5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-8b8f97ddea5d> in <cell line: 2>()
#       1 # If we try to access by using use decimal number,we will get errors.
# ----> 2 print(myString[1.5])
#
# TypeError: string indices must be integers

# %% [markdown]
# String Immutable

# %%
myString = "Hello"
myString[4]= 's' #strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-0a93ad76ba09> in <cell line: 2>()
#       1 myString = "Hello"
# ----> 2 myString[4]= 's' #strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
myString = "Hello"
newString = myString[:4] + 's'  # Create a new string with the desired change
print(newString)  # Output: "Hells"
# Out:
# Hells

# %% [markdown]
# Slicing the Strings

# %%
print(myString[2:5]) #Slicing 2nd to 5th character(start to end-1 index)
# Out:
# llo

# %%
print(myString[0:3])
# Out:
# Hel

# %%
#Slicing (start to all)
myString[2:]
# Out:
# 'llo'

# %%
myString[:4]
# Out:
# 'Hell'

# %%
myString[:]
# Out:
# 'Hello'

# %%
myString
# Out:
# 'Hello'

# %%
myString[4:1]
# Out:
# ''

# %%
myString[ : : 2] #slicing with increment
# Out:
# 'Hlo'

# %%
myString[-1 : -4 : -1]
# Out:
# 'oll'

# %%
myString[::-1] #print in reverse order.
# Out:
# 'olleH'

# %% [markdown]
# String Methods

# %% [markdown]
# . Some of the commonly used methods are lower(),upper(),join(),split(),find(),replace() etc.

# %% [markdown]
# Capitalize

# %%
 "good morning".capitalize() #capitalize opnly first letter and remaining all to small.
# Out:
# 'Good morning'

# %%
"good morning. Welcome".capitalize()
# Out:
# 'Good morning. welcome'

# %% [markdown]
# Title

# %%
a= "gOOd moRning"
a.title()
# Out:
# 'Good Morning'

# %%
"gOOd moRning".title()
# Out:
# 'Good Morning'

# %% [markdown]
# Upper

# %%
a.upper()   #convert compleate string to upper case.
# Out:
# 'GOOD MORNING'

# %% [markdown]
# Lower

# %%
a = "gOOd moRning"  #convert the string to lower case.
a.lower()
# Out:
# 'good morning'

# %%
st = 'hello my name is sam'  #split with space.
st.split()
# Out:
# ['hello', 'my', 'name', 'is', 'sam']

# %%
tweet = 'Go sports! #sports'
tweet.split() # Split by whitespace by default
# Out:
# ['Go', 'sports!', '#sports']

# %%
"This will split all words in a list".split()
# Out:
# ['This', 'will', 'split', 'all', 'words', 'in', 'a', 'list']

# %% [markdown]
# Join

# %%
''.join(['This', 'will', 'join', 'all', 'words', 'in', 'a', 'list'])
# Out:
# 'Thiswilljoinallwordsinalist'

# %% [markdown]
# Find

# %%
"Good Morning".find("M")    #To find a string in the input string
# Out:
# 5

# %% [markdown]
# Count

# %%
"Good Morning".count("o")   #To count how many times the string available in the main string
# Out:
# 3

# %% [markdown]
# Replace

# %%
s1 = "Good Morning"
s2 = s1.replace("Good","Bad")

# %%
my_Str='siva123'
print(my_Str.isalnum())
print(my_Str.isalpha())
print(my_Str.isdigit())
print(my_Str.istitle())
print(my_Str.isupper())
print(my_Str.islower())
print(my_Str.isspace())
print(my_Str.endswith('a'))
print(my_Str.startswith('s'))
# Out:
# True
# False
# False
# False
# False
# True
# False
# False
# True
